# %%
import json
import pandas as pd
from pandas.io.json import json_normalize
import pymongo
from pymongo import MongoClient

file_name = "../geotagged_tweets_20160812-0912.jsons"

# %%
user_cols = ['user.name', 'user.id_str', 'user.location', 'user.followers_count']

place_cols = ['place.id', 'place.url', 'place.place_type', 'place.name', 'place.full_name', 
              'place.country_code', 'place.country', 'place.bounding_box.type', 
              'place.bounding_box.coordinates']

entities_cols = ['entities.hashtags', 'entities.urls', 'entities.user_mentions', 'entities.symbols']

other_cols = ['created_at', 'text', 'truncated', 'retweet_count', 'favorite_count', 
               'filter_level', 'lang', 'timestamp_ms']

useful_cols = other_cols + user_cols + place_cols + entities_cols

# %%
client = MongoClient()
db = client.twitter
collection = db.inventory
data = pd.DataFrame(list(collection.find()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-cb212fd2e54e> in <module>
#      14 data = pd.DataFrame(list(collection.find()))
#      15
# ---> 16 data = data[useful_cols]
#
# ~/anaconda3/envs/tfgpu/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# ~/anaconda3/envs/tfgpu/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~/anaconda3/envs/tfgpu/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~/anaconda3/envs/tfgpu/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['user.location', 'place.place_type', 'user.followers_count', 'place.country_code', 'entities.hashtags', 'place.bounding_box.type', 'place.bounding_box.coordinates', 'place.url', 'user.id_str', 'place.id', 'place.name', 'user.name', 'entities.symbols', 'place.country', 'place.full_name', 'entities.user_mentions', 'entities.urls'] not in index"

# %%
data['user'] = data['user'].apply(lambda x: {} if pd.isna(x) else x)
user = json_normalize(data['user'], errors = 'ignore')
user.columns = ['user.' + str(col) for col in user.columns]
user = user[user_cols]

print("USER")

data['place'] = data['place'].apply(lambda x: {} if pd.isna(x) else x)
place = json_normalize(data['place'], errors = 'ignore')
place.columns = ['place.' + str(col) for col in place.columns]
place = place[place_cols]

print("PLACE")

data['entities'] = data['entities'].apply(lambda x: {} if pd.isna(x) else x)
entities = json_normalize(data['entities'], errors = 'ignore')
entities.columns = ['entities.' + str(col) for col in entities.columns]
entities = entities[entities_cols]

print("ENTITIES")
# Out:
# USER
# PLACE
# ENTITIES

# %%
data = data.drop(columns=['user', 'place', 'entities'])
data = pd.concat([data, user, place, entities], axis=1, sort=False)[useful_cols]
data.head()
# Out:
#                        created_at  \
# 0  Fri Aug 12 10:04:00 +0000 2016
# 1  Fri Aug 12 10:04:02 +0000 2016
# 2  Fri Aug 12 10:04:21 +0000 2016
# 3  Fri Aug 12 10:04:10 +0000 2016
# 4  Fri Aug 12 10:04:30 +0000 2016
#
#                                                 text  truncated  \
# 0  @theblaze @realDonaldTrump https://t.co/TY9DlZ...      False
# 1  @BarackObama \n@FBI\n@LORETTALYNCH \nALL IN CO...      False
# 2  @HillaryClinton he will do in one year all the...      False
# 3  @theblaze @realDonaldTrump https://t.co/n050DB...      False
# 4  #CNN #newday clear #Trump deliberately throwin...      False
#
#    retweet_count  favorite_count filter_level lang   timestamp_ms  \
# 0              0               0          low  und  1470996240225
# 1              0               0          low   en  1470996242194
# 2              0               0          low   en  1470996261125
# 3              0               0          low  und  1470996250817
# 4              0               0          low   en  1470996270035
#
#         user.name user.id_str  ...   place.name      place.full_name  \
# 0       GIL DUPUY   366636488  ...    Frontenac        Frontenac, MO
# 1     Red Octopus    82496193  ...  Baton Rouge      Baton Rouge, LA
# 2    JanJorgenson    44032624  ...    Melbourne  Melbourne, Victoria
# 3       GIL DUPUY   366636488  ...    Frontenac        Frontenac, MO
# 4  Beverly Spence   769208504  ...    Baltimore        Baltimore, MD
#
#   place.country_code  place.country place.bounding_box.type  \
# 0                 US  United States                 Polygon
# 1                 US  United States                 Polygon
# 2                 AU      Australia                 Polygon
# 3                 US  United States                 Polygon
# 4                 US  United States                 Polygon
#
#                       place.bounding_box.coordinates  \
# 0  [[[-90.433909, 38.606163], [-90.433909, 38.647...
# 1  [[[-91.218994, 30.354161], [-91.218994, 30.564...
# 2  [[[144.593742, -38.433859], [144.593742, -37.5...
# 3  [[[-90.433909, 38.606163], [-90.433909, 38.647...
# 4  [[[-76.711521, 39.197211], [-76.711521, 39.372...
#
#                                    entities.hashtags  \
# 0                                                 []
# 1  [{'text': 'NOJUSTICE', 'indices': [62, 72]}, {...
# 2                                                 []
# 3                                                 []
# 4  [{'text': 'CNN', 'indices': [0, 4]}, {'text': ...
#
#                                        entities.urls  \
# 0                                                 []
# 1  [{'url': 'https://t.co/5GMNZq40V3', 'expanded_...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                               entities.user_mentions entities.symbols
# 0  [{'screen_name': 'theblaze', 'name': 'TheBlaze...               []
# 1  [{'screen_name': 'BarackObama', 'name': 'Barac...               []
# 2  [{'screen_name': 'HillaryClinton', 'name': 'Hi...               []
# 3  [{'screen_name': 'theblaze', 'name': 'TheBlaze...               []
# 4                                                 []               []
#
# [5 rows x 25 columns]

# %%
data
# Out:
#                             created_at  \
# 0       Fri Aug 12 10:04:00 +0000 2016
# 1       Fri Aug 12 10:04:02 +0000 2016
# 2       Fri Aug 12 10:04:21 +0000 2016
# 3       Fri Aug 12 10:04:10 +0000 2016
# 4       Fri Aug 12 10:04:30 +0000 2016
# ...                                ...
# 657302  Mon Sep 12 13:20:33 +0000 2016
# 657303  Mon Sep 12 13:20:36 +0000 2016
# 657304  Mon Sep 12 13:20:38 +0000 2016
# 657305  Mon Sep 12 13:20:32 +0000 2016
# 657306  Mon Sep 12 13:20:48 +0000 2016
#
#                                                      text  truncated  \
# 0       @theblaze @realDonaldTrump https://t.co/TY9DlZ...      False
# 1       @BarackObama \n@FBI\n@LORETTALYNCH \nALL IN CO...      False
# 2       @HillaryClinton he will do in one year all the...      False
# 3       @theblaze @realDonaldTrump https://t.co/n050DB...      False
# 4       #CNN #newday clear #Trump deliberately throwin...      False
# ...                                                   ...        ...
# 657302  @CarolCNN if MSM were honest watch any utube v...      False
# 657303  #EEUU\nNeumonía obliga a @HillaryClinton a can...      False
# 657304  It's interesting that Hillary Clinton's crowds...      False
# 657305  TRUMP U, TAXES ,WEIRD MEDICAL REPORT WITH A WH...      False
# 657306  @TeamTrump @KellyannePolls @realDonaldTrump @f...      False
#
#         retweet_count  favorite_count filter_level lang   timestamp_ms  \
# 0                   0               0          low  und  1470996240225
# 1                   0               0          low   en  1470996242194
# 2                   0               0          low   en  1470996261125
# 3                   0               0          low  und  1470996250817
# 4                   0               0          low   en  1470996270035
# ...               ...             ...          ...  ...            ...
# 657302              0               0          low   en  1473686433874
# 657303              0               0          low   es  1473686436682
# 657304              0               0          low   en  1473686438961
# 657305              0               0          low   en  1473686432363
# 657306              0               0          low   en  1473686448096
#
#                user.name         user.id_str  ...    place.name  \
# 0              GIL DUPUY           366636488  ...     Frontenac
# 1            Red Octopus            82496193  ...   Baton Rouge
# 2           JanJorgenson            44032624  ...     Melbourne
# 3              GIL DUPUY           366636488  ...     Frontenac
# 4         Beverly Spence           769208504  ...     Baltimore
# ...                  ...                 ...  ...           ...
# 657302           Karen B  716017946166857728  ...  Coral Gables
# 657303  La Razon Digital            44489439  ...       Bolivia
# 657304    Robert Chaffin          3241116564  ...     Fairbanks
# 657305   Sheryl Berghoff           569487350  ...     San Diego
# 657306             Linda           142113417  ...       Florida
#
#             place.full_name place.country_code  place.country  \
# 0             Frontenac, MO                 US  United States
# 1           Baton Rouge, LA                 US  United States
# 2       Melbourne, Victoria                 AU      Australia
# 3             Frontenac, MO                 US  United States
# 4             Baltimore, MD                 US  United States
# ...                     ...                ...            ...
# 657302     Coral Gables, FL                 US  United States
# 657303              Bolivia                 BO        Bolivia
# 657304        Fairbanks, AK                 US  United States
# 657305        San Diego, CA                 US  United States
# 657306         Florida, USA                 US  United States
#
#        place.bounding_box.type  \
# 0                      Polygon
# 1                      Polygon
# 2                      Polygon
# 3                      Polygon
# 4                      Polygon
# ...                        ...
# 657302                 Polygon
# 657303                 Polygon
# 657304                 Polygon
# 657305                 Polygon
# 657306                 Polygon
#
#                            place.bounding_box.coordinates  \
# 0       [[[-90.433909, 38.606163], [-90.433909, 38.647...
# 1       [[[-91.218994, 30.354161], [-91.218994, 30.564...
# 2       [[[144.593742, -38.433859], [144.593742, -37.5...
# 3       [[[-90.433909, 38.606163], [-90.433909, 38.647...
# 4       [[[-76.711521, 39.197211], [-76.711521, 39.372...
# ...                                                   ...
# 657302  [[[-80.297165, 25.627038], [-80.297165, 25.771...
# 657303  [[[-69.640762, -22.897682], [-69.640762, -9.66...
# 657304  [[[-147.81382, 64.810474], [-147.81382, 64.865...
# 657305  [[[-117.282538, 32.53962], [-117.282538, 33.08...
# 657306  [[[-87.634643, 24.396308], [-87.634643, 31.001...
#
#                                         entities.hashtags  \
# 0                                                      []
# 1       [{'text': 'NOJUSTICE', 'indices': [62, 72]}, {...
# 2                                                      []
# 3                                                      []
# 4       [{'text': 'CNN', 'indices': [0, 4]}, {'text': ...
# ...                                                   ...
# 657302                                                 []
# 657303              [{'text': 'EEUU', 'indices': [0, 5]}]
# 657304                                                 []
# 657305                                                 []
# 657306                                                 []
#
#                                             entities.urls  \
# 0                                                      []
# 1       [{'url': 'https://t.co/5GMNZq40V3', 'expanded_...
# 2                                                      []
# 3                                                      []
# 4                                                      []
# ...                                                   ...
# 657302                                                 []
# 657303  [{'url': 'https://t.co/ovXe59kn0n', 'expanded_...
# 657304  [{'url': 'https://t.co/lrq2SOOwSO', 'expanded_...
# 657305  [{'url': 'https://t.co/2qDahl7A9n', 'expanded_...
# 657306                                                 []
#
#                                    entities.user_mentions entities.symbols
# 0       [{'screen_name': 'theblaze', 'name': 'TheBlaze...               []
# 1       [{'screen_name': 'BarackObama', 'name': 'Barac...               []
# 2       [{'screen_name': 'HillaryClinton', 'name': 'Hi...               []
# 3       [{'screen_name': 'theblaze', 'name': 'TheBlaze...               []
# 4                                                      []               []
# ...                                                   ...              ...
# 657302  [{'screen_name': 'CarolCNN', 'name': 'Carol Co...               []
# 657303  [{'screen_name': 'HillaryClinton', 'name': 'Hi...               []
# 657304                                                 []               []
# 657305                                                 []               []
# 657306  [{'screen_name': 'TeamTrump', 'name': 'Officia...               []
#
# [657307 rows x 25 columns]

# %%
# Out:
#      user.id user.id_str       user.name user.screen_name user.location  \
# 0  366636488   366636488       GIL DUPUY          DUPUY77         Miami
# 1   82496193    82496193     Red Octopus       redoctapus  Ogletown, DE
# 2   44032624    44032624    JanJorgenson         jjorgi30     Australia
# 3  366636488   366636488       GIL DUPUY          DUPUY77         Miami
# 4  769208504   769208504  Beverly Spence         bspence5          None
#
#                user.url                                   user.description  \
# 0  http://ggm-dupuy.com  Fashion photographer, love action and adventur...
# 1                  None  AWSCWI Pipefitter USAF NRA I remember USA, Hun...
# 2                  None  The best movies are written and directed by pe...
# 3  http://ggm-dupuy.com  Fashion photographer, love action and adventur...
# 4                  None  Retired, political wonk mother of one grandmot...
#
#    user.protected  user.verified  user.followers_count  ...  \
# 0           False          False                   186  ...
# 1           False          False                   531  ...
# 2           False          False                   180  ...
# 3           False          False                   186  ...
# 4           False          False                  2652  ...
#
#    user.profile_text_color  user.profile_use_background_image  \
# 0                   333333                               True
# 1                   000000                              False
# 2                   3E4415                               True
# 3                   333333                               True
# 4                   333333                               True
#
#                               user.profile_image_url  \
# 0  http://pbs.twimg.com/profile_images/7609156129...
# 1  http://pbs.twimg.com/profile_images/6883746403...
# 2  http://pbs.twimg.com/profile_images/7200177636...
# 3  http://pbs.twimg.com/profile_images/7609156129...
# 4  http://pbs.twimg.com/profile_images/3108377856...
#
#                         user.profile_image_url_https user.default_profile  \
# 0  https://pbs.twimg.com/profile_images/760915612...                False
# 1  https://pbs.twimg.com/profile_images/688374640...                False
# 2  https://pbs.twimg.com/profile_images/720017763...                False
# 3  https://pbs.twimg.com/profile_images/760915612...                False
# 4  https://pbs.twimg.com/profile_images/310837785...                False
#
#    user.default_profile_image user.following  user.follow_request_sent  \
# 0                       False           None                      None
# 1                       False           None                      None
# 2                       False           None                      None
# 3                       False           None                      None
# 4                       False           None                      None
#
#   user.notifications                            user.profile_banner_url
# 0               None                                                NaN
# 1               None  https://pbs.twimg.com/profile_banners/82496193...
# 2               None  https://pbs.twimg.com/profile_banners/44032624...
# 3               None                                                NaN
# 4               None                                                NaN
#
# [5 rows x 38 columns]

# %%
df1["created_at"] = pd.to_datetime(df1["created_at"], format="")

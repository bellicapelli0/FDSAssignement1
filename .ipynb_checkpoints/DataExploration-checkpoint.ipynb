# %%
import json
import pandas as pd
file_name = "../geotagged_tweets_20160812-0912.jsons"

data = json.load(open("test.json", "r"))

# %%
data = []
with open(file_name, "r") as file:
    line = file.readline()
    cnt=1
    while line:
        data.append(json.loads(line))
        line = file.readline()
        cnt+=1

# %%
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#                        created_at                  id              id_str  \
# 0  Fri Aug 12 10:04:00 +0000 2016  764039724818272256  764039724818272256
# 1  Fri Aug 12 10:04:02 +0000 2016  764039733076897792  764039733076897792
# 2  Fri Aug 12 10:04:10 +0000 2016  764039769244348417  764039769244348417
# 3  Fri Aug 12 10:04:21 +0000 2016  764039812479225856  764039812479225856
# 4  Fri Aug 12 10:04:30 +0000 2016  764039849850482689  764039849850482689
#
#                                                 text  \
# 0  @theblaze @realDonaldTrump https://t.co/TY9DlZ...
# 1  @BarackObama \n@FBI\n@LORETTALYNCH \nALL IN CO...
# 2  @theblaze @realDonaldTrump https://t.co/n050DB...
# 3  @HillaryClinton he will do in one year all the...
# 4  #CNN #newday clear #Trump deliberately throwin...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
# 1  <a href="http://twitter.com/download/android" ...      False
# ...

# %%
len(data)

useful_cols = ["created_at", "text". "truncated", "user", "geo", "coordinates", "place",
               "retweet_count", "favorite_count", "entities", "possibly_sensitive", "filter_level", "lang",
               "timestamp_ms"]
# Out:
# 657307

# %%
data[0]
# Out:
# {'created_at': 'Fri Aug 12 10:04:00 +0000 2016',
#  'id': 764039724818272256,
#  'id_str': '764039724818272256',
#  'text': '@theblaze @realDonaldTrump https://t.co/TY9DlZ584c',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': 764038820476051456,
#  'in_reply_to_status_id_str': '764038820476051456',
#  'in_reply_to_user_id': 10774652,
#  'in_reply_to_user_id_str': '10774652',
#  'in_reply_to_screen_name': 'theblaze',
#  'user': {'id': 366636488,
#   'id_str': '366636488',
#   'name': 'GIL DUPUY',
#   'screen_name': 'DUPUY77',
#   'location': 'Miami',
#   'url': 'http://ggm-dupuy.com',
#   'description': "Fashion photographer, love action and adventure, care for the less fortunate, don't tolerate any kind of racism regardless of race or religion",
#   'protected': False,
#   'verified': False,
#   'followers_count': 186,
#   'friends_count': 446,
#   'listed_count': 19,
# ...
